# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Running cells with 'venv (3.14.3) (Python 3.14.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/tedvtorov/Desktop/MISIS/misis_ml_course_sem6/venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
CS_data.describe(include="all")

# %%
T_data.describe(exclude=[np.number])

# %%
sns.histplot(data=CS_data, x="channel_name")

# %%
CS_data.channel_name.value_counts()

# %%
sns.catplot(data=CS_data, x="channel_name", y="CSAT Score", kind="bar")

# %%
counts = CS_data.category.value_counts()
sns.barplot(x=counts.index, y=counts.values)
plt.xticks(rotation=45)
plt.show()
